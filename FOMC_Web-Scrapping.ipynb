# %% [markdown]
# # FOMC Statement Scraper
# This notebook downloads FOMC statements from the Fed website based on dates provided in a file called `dates.sort.txt`. Each statement is saved in a text file.

# %%
# Importing required libraries
from urllib.request import Request, urlopen

from bs4 import BeautifulSoup
from urllib.request import urlopen
from time import sleep
import re, csv, os

# %%
# Setting the output directory to save statements
outdir = os.path.join('statements', 'statements.raw')
os.makedirs(outdir, exist_ok=True)

# %% [markdown]
# ### Function to get URL of FOMC statement based on date

# %%
def FOMCstatementURL(date):
    year = date[0:4]
    dateInt = int(date)

    if dateInt == 20081216:
        urlout = 'http://www.federalreserve.gov/newsevents/press/monetary/' + date + 'b.htm'
    elif 19990501 <= dateInt < 20020331:
        urlout = 'http://www.federalreserve.gov/boarddocs/press/general/' + year + '/' + date + '/'
    elif 20020501 <= dateInt < 20030000:
        urlout = 'http://www.federalreserve.gov/boarddocs/press/monetary/' + year + '/' + date + '/'
    elif 20030000 <= dateInt < 20060000:
        urlout = 'http://www.federalreserve.gov/boarddocs/press/monetary/' + year + '/' + date + '/default.htm'
    elif dateInt >= 20050000:
        urlout = 'http://www.federalreserve.gov/newsevents/press/monetary/' + date + 'a.htm'
    return urlout

# %% [markdown]
# ### Function to get and extract the statement from the webpage

# %%
def getStatement(mtgDate):
    print(' Pulling:', mtgDate)

    url = FOMCstatementURL(mtgDate)
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    html = urlopen(req).read()

    soup = BeautifulSoup(html, 'html.parser')
    allText = soup.get_text(" ")

    # Safe start match
    start_match = re.search(r"[Ff]or\s[Ii]mmediate\s[Rr]elease", allText)
    if not start_match:
        print(f" Start pattern not found for {mtgDate}")
        return ""

    statementText = allText[start_match.start():]

    # Safe end match
    end_match = re.search(r"[0-9]{4}\s[Mm]onetary\s[Pp]olicy", statementText)
    if end_match:
        statementText = statementText[:end_match.start()]
    else:
        print(f" End pattern not found for {mtgDate}, saving full content after start")

    # Clean special characters
    statementText = statementText.encode('ascii', 'ignore').decode('ascii')

    return statementText

# %% [markdown]
# ### Main logic to read dates and save statements

# %%
def main():
    # Read the date list
    date_path = os.path.join('data', 'dates.sort.txt')
    releaseDates = [line.strip() for line in open(date_path, 'r')]

    for releaseDate in releaseDates:
        data = getStatement(releaseDate)
        sleep(2)  # Be polite to the server

        # Fix for special case
        if "20070618" in releaseDate:
            releaseDate = "20070628"

        filename = f"statement.fomc.{releaseDate}.txt"
        filepath = os.path.join(outdir, filename)
        with open(filepath, 'w') as f:
            f.write(data)

# %% [markdown]
# ### Run the main function

# %%
main()
# Out:
#  Pulling: 19990518
#  Pulling: 19990630
#  Pulling: 19990824
#  Pulling: 19991005
#  Pulling: 19991116
#  Pulling: 19991221
#  Pulling: 20000202
#  Pulling: 20000321
#  Pulling: 20000516
#  Pulling: 20000628
#  Pulling: 20000822
#  Pulling: 20001003
#  Pulling: 20001115
#  Pulling: 20001219
#  Pulling: 20010131
#  Pulling: 20010320
#  Pulling: 20010515
#  Pulling: 20010627
#  Pulling: 20010821
#  Pulling: 20011002
#  Pulling: 20011106
#  Pulling: 20011211
#  Pulling: 20020130
#  Pulling: 20020319
#  Pulling: 20020507
#  Pulling: 20020626
#  Pulling: 20020813
#  Pulling: 20020924
#  Pulling: 20021106
#  Pulling: 20021210
#  Pulling: 20030129
#  Pulling: 20030318
#  Pulling: 20030506
#  Pulling: 20030625
#  Pulling: 20030812
#  Pulling: 20030916
#  Pulling: 20031028
#  Pulling: 20031209
#  Pulling: 20040128
#  Pulling: 20040316
#  Pulling: 20040504
#  Pulling: 20040630
#  Pulling: 20040810
#  Pulling: 20040921
#  Pulling: 20041110
#  Pulling: 20041214
#  Pulling: 20050202
#  Pulling: 20050322
#  Pulling: 20050503
#  Pulling: 20050630
#  Pulling: 20050809
#  Pulling: 20050920
#  Pulling: 20051101
#  Pulling: 20051213
#  Pulling: 20060131
#  End pattern not found for 20060131, saving full content after start
#  Pulling: 20060328
#  End pattern not found for 20060328, saving full content after start
#  Pulling: 20060510
#  End pattern not found for 20060510, saving full content after start
#  Pulling: 20060629
#  End pattern not found for 20060629, saving full content after start
#  Pulling: 20060808
#  End pattern not found for 20060808, saving full content after start
#  Pulling: 20060920
#  End pattern not found for 20060920, saving full content after start
#  Pulling: 20061025
#  End pattern not found for 20061025, saving full content after start
#  Pulling: 20061212
#  End pattern not found for 20061212, saving full content after start
#  Pulling: 20070131
#  End pattern not found for 20070131, saving full content after start
#  Pulling: 20070321
#  End pattern not found for 20070321, saving full content after start
#  Pulling: 20070509
#  End pattern not found for 20070509, saving full content after start
#  Pulling: 20070618
#  End pattern not found for 20070618, saving full content after start
#  Pulling: 20070807
#  End pattern not found for 20070807, saving full content after start
#  Pulling: 20070918
#  End pattern not found for 20070918, saving full content after start
#  Pulling: 20071031
#  End pattern not found for 20071031, saving full content after start
#  Pulling: 20071211
#  End pattern not found for 20071211, saving full content after start
#  Pulling: 20080130
#  End pattern not found for 20080130, saving full content after start
#  Pulling: 20080318
#  End pattern not found for 20080318, saving full content after start
#  Pulling: 20080430
#  End pattern not found for 20080430, saving full content after start
#  Pulling: 20080625
#  End pattern not found for 20080625, saving full content after start
#  Pulling: 20080805
#  End pattern not found for 20080805, saving full content after start
#  Pulling: 20080916
#  End pattern not found for 20080916, saving full content after start
#  Pulling: 20081029
#  End pattern not found for 20081029, saving full content after start
#  Pulling: 20081216
#  End pattern not found for 20081216, saving full content after start
#  Pulling: 20090128
#  End pattern not found for 20090128, saving full content after start
#  Pulling: 20090318
#  End pattern not found for 20090318, saving full content after start
#  Pulling: 20090429
#  End pattern not found for 20090429, saving full content after start
#  Pulling: 20090624
#  End pattern not found for 20090624, saving full content after start
#  Pulling: 20090812
#  End pattern not found for 20090812, saving full content after start
#  Pulling: 20090923
#  End pattern not found for 20090923, saving full content after start
#  Pulling: 20091104
#  End pattern not found for 20091104, saving full content after start
#  Pulling: 20091216
#  End pattern not found for 20091216, saving full content after start
#  Pulling: 20100127
#  End pattern not found for 20100127, saving full content after start
#  Pulling: 20100316
#  End pattern not found for 20100316, saving full content after start
#  Pulling: 20100428
#  End pattern not found for 20100428, saving full content after start
#  Pulling: 20100623
#  End pattern not found for 20100623, saving full content after start
#  Pulling: 20100810
#  End pattern not found for 20100810, saving full content after start
#  Pulling: 20100921
#  End pattern not found for 20100921, saving full content after start
#  Pulling: 20101103
#  End pattern not found for 20101103, saving full content after start
#  Pulling: 20101214
#  End pattern not found for 20101214, saving full content after start
#  Pulling: 20110126
#  End pattern not found for 20110126, saving full content after start
#  Pulling: 20110315
#  End pattern not found for 20110315, saving full content after start
#  Pulling: 20110427
#  End pattern not found for 20110427, saving full content after start
#  Pulling: 20110622
#  End pattern not found for 20110622, saving full content after start
#  Pulling: 20110809
#  End pattern not found for 20110809, saving full content after start
#  Pulling: 20110921
#  End pattern not found for 20110921, saving full content after start
#  Pulling: 20111102
#  End pattern not found for 20111102, saving full content after start
#  Pulling: 20111213
#  End pattern not found for 20111213, saving full content after start
#  Pulling: 20120125
#  End pattern not found for 20120125, saving full content after start
#  Pulling: 20120313
#  End pattern not found for 20120313, saving full content after start
#  Pulling: 20120425
#  End pattern not found for 20120425, saving full content after start
#  Pulling: 20120620
#  End pattern not found for 20120620, saving full content after start
#  Pulling: 20120801
#  End pattern not found for 20120801, saving full content after start
#  Pulling: 20120913
#  End pattern not found for 20120913, saving full content after start
#  Pulling: 20121024
#  End pattern not found for 20121024, saving full content after start
#  Pulling: 20121212
#  End pattern not found for 20121212, saving full content after start
#  Pulling: 20130130
#  End pattern not found for 20130130, saving full content after start
#  Pulling: 20130320
#  End pattern not found for 20130320, saving full content after start
#  Pulling: 20130501
#  End pattern not found for 20130501, saving full content after start
#  Pulling: 20130619
#  End pattern not found for 20130619, saving full content after start
#  Pulling: 20130731
#  End pattern not found for 20130731, saving full content after start
#  Pulling: 20130918
#  End pattern not found for 20130918, saving full content after start
#  Pulling: 20131030
#  End pattern not found for 20131030, saving full content after start
#  Pulling: 20131218
#  End pattern not found for 20131218, saving full content after start
#  Pulling: 20140129
#  End pattern not found for 20140129, saving full content after start
#  Pulling: 20140319
#  End pattern not found for 20140319, saving full content after start
#  Pulling: 20140430
#  End pattern not found for 20140430, saving full content after start
#  Pulling: 20140618
#  End pattern not found for 20140618, saving full content after start
#  Pulling: 20140730
#  End pattern not found for 20140730, saving full content after start
#  Pulling: 20140917
#  End pattern not found for 20140917, saving full content after start
#  Pulling: 20141029
#  End pattern not found for 20141029, saving full content after start
#  Pulling: 20141217
#  End pattern not found for 20141217, saving full content after start
#  Pulling: 20150128
#  End pattern not found for 20150128, saving full content after start
#  Pulling: 20150318
#  End pattern not found for 20150318, saving full content after start
#  Pulling: 20150429
#  End pattern not found for 20150429, saving full content after start
#  Pulling: 20150617
#  End pattern not found for 20150617, saving full content after start
#  Pulling: 20150729
#  End pattern not found for 20150729, saving full content after start
#  Pulling: 20150917
#  End pattern not found for 20150917, saving full content after start
#  Pulling: 20151028
#  End pattern not found for 20151028, saving full content after start
#  Pulling: 20151216
#  End pattern not found for 20151216, saving full content after start
